# %% [markdown]
# ## EDA on Advanced House Price Prediction Dataset

# %% [markdown]
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# %matplotlib inline

# %%
train = pd.read_csv("../house_price.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### Exploratory Data Analysis
# 1. Missing Values
# 2. All The Numerical Variables
# 3. Distribution of the Numerical Variables
# 4. Categorical Variables
# 5. Cardinality of Categorical Variables
# 6. Outliers
# 7. Relationship between independent and dependent feature(SalePrice)

# %% [markdown]
# #### Missing Values

# %%
## Here we will check the percentage of nan values present in each feature

train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train.isnull().mean()
# Out:
# Id               0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage      0.177397
# LotArea          0.000000
#                    ...
# MoSold           0.000000
# YrSold           0.000000
# SaleType         0.000000
# SaleCondition    0.000000
# SalePrice        0.000000
# Length: 81, dtype: float64

# %%
features_with_na = [feat for feat in train.columns if train[feat].isnull().sum()>0 ]

# %%
features_with_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for feat in features_with_na:
    print("null values% of  {} : {}  ".format(feat, round(train[feat].isnull().mean(),4)))
# Out:
# null values% of  LotFrontage : 0.1774
# null values% of  Alley : 0.9377
# null values% of  MasVnrType : 0.0055
# null values% of  MasVnrArea : 0.0055
# null values% of  BsmtQual : 0.0253
# null values% of  BsmtCond : 0.0253
# null values% of  BsmtExposure : 0.026
# null values% of  BsmtFinType1 : 0.0253
# null values% of  BsmtFinType2 : 0.026
# null values% of  Electrical : 0.0007
# null values% of  FireplaceQu : 0.4726
# null values% of  GarageType : 0.0555
# null values% of  GarageYrBlt : 0.0555
# null values% of  GarageFinish : 0.0555
# null values% of  GarageQual : 0.0555
# null values% of  GarageCond : 0.0555
# null values% of  PoolQC : 0.9952
# null values% of  Fence : 0.8075
# null values% of  MiscFeature : 0.963

# %% [markdown]
# ### Since they are many missing values, we need to find the relationship between missing values and Sales Price
#
# Let's plot some diagram for this relationship

# %%
for feature in features_with_na:
    data = train.copy()
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# ###### The relation between the missing values and the output variable is clearly visible, hence we need to replace the missing values with something meaningful in feature engineering phase.

# %% [markdown]
# ##### Some features like id is not needed

# %%
len(train['Id'])
# Out:
# 1460

# %% [markdown]
# ### Numerical Features

# %%
numerical_features = [feature for feature in train.columns if train[feature].dtypes != 'O']
print("Number of Numerical Featues is {}".format(len(numerical_features)))
train[numerical_features].head(2)
# Out:
# Number of Numerical Featues is 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710             1             0
# 1      1262         0             0       1262             0             1
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0         2         1             3             1             8           0
# 1         2         0             3             1             6           1
#
# ...

# %% [markdown]
# #### Temporal Variables(Eg: Datetime Variables)
#
# From the Dataset we have 4 year variables. We have extract information from the datetime variables like no of years or no of days. One example in this specific scenario can be difference in years between the year the house was built and the year the house was sold.

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
year_features = [feature for feature in train.columns if 'Yr' in feature or 'Year' in feature ]
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
train[year_features]
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          2003          2003       2003.0    2008
# 1          1976          1976       1976.0    2007
# 2          2001          2002       2001.0    2008
# 3          1915          1970       1998.0    2006
# 4          2000          2000       2000.0    2008
# ...         ...           ...          ...     ...
# 1455       1999          2000       1999.0    2007
# 1456       1978          1988       1978.0    2010
# 1457       1941          2006       1941.0    2010
# 1458       1950          1996       1950.0    2010
# 1459       1965          1965       1965.0    2008
#
# [1460 rows x 4 columns]

# %%
for feature in year_features:
    print(feature, train[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %% [markdown]
# ### Analyse the temporal vairables, check whether any relation between year sold and Price

# %%
train.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel("Year Sold")
plt.ylabel("Median House Price")
plt.title("House Price vs Year Sold")
# Out:
# Text(0.5, 1.0, 'House Price vs Year Sold')

# %% [markdown]
# ### we compare all the year features and sale price

# %%
train.groupby('YearRemodAdd')['SalePrice'].median().plot()
plt.xlabel("Year Remodified")
plt.ylabel("Median House Price")
plt.title("House Price vs Year Remodified")
# Out:
# Text(0.5, 1.0, 'House Price vs Year Remodified')

# %%
train.groupby('YearBuilt')['SalePrice'].median().plot()
plt.xlabel("Year Built")
plt.ylabel("Median House Price")
plt.title("House Price vs Year Built")
# Out:
# Text(0.5, 1.0, 'House Price vs Year Built')

# %%
### Compare the difference between the YEar sold and the other year features
data = train.copy()
for feature in year_features:
    
    if feature == 'YrSold': continue
    data[feature] = data['YrSold'] - data[feature]
    plt.scatter(data[feature], data['SalePrice'])
    plt.title(feature)
    plt.show()

# %%
## Numerical variables are usually of 2 type
## 1. Continous variable and Discrete Variables

numerical_features
discrete_numerical_features = [feature for feature in numerical_features if train[feature].nunique()<25 and feature not in year_features + ['Id']]

print("Number of Numerical Features are {}".format(len(discrete_numerical_features)))
# Out:
# Number of Numerical Features are 17

# %%
discrete_numerical_features
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
train[discrete_numerical_features].head(3)
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# 0           0           2          0         0        0       2
# 1           1           2          0         0        0       5
# 2           1           2          0         0        0       9

# %%
## Lets Find the realtionship between them and Sale PRice


for feature in discrete_numerical_features:
    data = train.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# #### There is a relationship between variable number and SalePrice

# %% [markdown]
# ## Continuous Features

# %%
continuous_features = [feature for feature in numerical_features if feature not in discrete_numerical_features + year_features + ['Id'] ]
print("Number of continuous features are {}".format(len(continuous_features)))
# Out:
# Number of continuous features are 16

# %%
##Lets understand the continuous feature by plotting histogram
data = train.copy()
for feature in continuous_features:
    data[feature].hist(bins=30)
    plt.title(feature)
    plt.show()
