# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot(x='total_bill', y='tip', data=df,kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=df,kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='sex')

# %%
sns.distplot(df['total_bill'], bins = 30, kde=False)

# %%
sns.distplot(df['total_bill'], bins = 30, kde=True)

# %%
#Categorical plots
sns.countplot(x='sex', data=df)

# %%
sns.barplot(x='sex',y ='total_bill', data=df, estimator=np.average)

# %%
sns.barplot(y='sex',x='total_bill', data=df, estimator=np.average)

# %%
sns.boxplot(x='sex', y='total_bill', data = df)

# %%
sns.boxplot( data = df,orient='v')

# %%
sns.violinplot(x='total_bill', y='day', data=df)
